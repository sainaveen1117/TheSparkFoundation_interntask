# %% [markdown]
# # Exploratory Data Analysis On SuperStore Dataset

# %%
##Importing required libraries
import pandas as pd                         
import numpy as np                       
import seaborn as sns                  
import matplotlib.pyplot as plt            
from sklearn import datasets

# %%
data=pd.read_csv("C:/Users/Naveen/Desktop/Project/SampleSuperstore.csv") 
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# Statistics about data

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# Information about data

# %%
data.info()#to know the data types in our data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
data.isnull().sum() #Checking for Null values
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data.shape #to know the no of rows and coloumns
# Out:
# (9994, 13)

# %%
data.nunique() #count the distinct observations
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
data.drop_duplicates(inplace=True) #drop the duplicate values

# %%
data.duplicated().sum() #Now there are no duplicate values
# Out:
# 0

# %% [markdown]
# Data visualisation

# %%
data.groupby('Segment')['Sales','Profit'].sum().plot.bar()
plt.xlabel("Segment")
plt.ylabel("Sales and Profit")
plt.title("Segment vs Sales & Profit")
# Out:
# <ipython-input-18-c8286d9f3ed2>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Segment')['Sales','Profit'].sum().plot.bar()
# Text(0.5, 1.0, 'Segment vs Sales & Profit')

# %% [markdown]
# In this segment vs sales & profit we can observe that profit is very less even though sales happen a lot which is inevitable.We can do something to increase our profits like-
# 1)Getting feedbacks
# 2) Customer interaction programs
# 3) Providing better offers for bulk orders

# %%
data.groupby('Region')['Sales','Profit','Quantity'].sum().plot.bar()
plt.xlabel("Region")
plt.ylabel("Sales, Profit, Quantiy")
plt.title("Region vs Sales,Profit & Quantity")
# Out:
# <ipython-input-20-f0e556cd2f90>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Region')['Sales','Profit','Quantity'].sum().plot.bar()
# Text(0.5, 1.0, 'Region vs Sales,Profit & Quantity')

# %%
data.groupby('Category')['Sales','Profit','Quantity'].sum().plot.bar()
plt.xlabel("Category")
plt.ylabel("Sales, Profit, Quantiy")
plt.title("Category vs Sales,Profit & Quantity")
# Out:
# <ipython-input-21-f1018b82721b>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Category')['Sales','Profit','Quantity'].sum().plot.bar()
# Text(0.5, 1.0, 'Category vs Sales,Profit & Quantity')

# %%
data.groupby('Sub-Category')['Sales','Profit','Quantity'].sum().plot.bar()
plt.xlabel("Sub-Category")
plt.ylabel("Sales, Profit, Quantiy")
plt.title("Sub-Category vs Sales,Profit & Quantity")
# Out:
# <ipython-input-23-63b3a8b7190e>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Sub-Category')['Sales','Profit','Quantity'].sum().plot.bar()
# Text(0.5, 1.0, 'Sub-Category vs Sales,Profit & Quantity')

# %%
data.groupby('Quantity')['Discount'].sum().plot.bar()
plt.xlabel("Quantity")
plt.ylabel(" Discount")
plt.title("Quantity vs Discount")
# Out:
# Text(0.5, 1.0, 'Quantity vs Discount')

# %%
data.groupby('State')['Sales','Profit'].sum().plot.bar(figsize=(15,9))
plt.xlabel("State")
plt.ylabel("Sales and Profit")
plt.title("States vs Sales & Profit")
# Out:
# <ipython-input-25-7da71fa784eb>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('State')['Sales','Profit'].sum().plot.bar(figsize=(15,9))
# Text(0.5, 1.0, 'States vs Sales & Profit')

# %%
sns.lineplot(x=data['Quantity'], y=data['Profit'])
plt.title("Quantity vs Profit")
# Out:
# Text(0.5, 1.0, 'Quantity vs Profit')

# %%
sns.lineplot(x=data['Sales'], y=data['Profit'])
plt.title("Sales vs Profit")
# Out:
# Text(0.5, 1.0, 'Sales vs Profit')

# %%
sns.lineplot(x=data['Quantity'], y=data['Discount'])
plt.title("Quantity vs Discount")
# Out:
# Text(0.5, 1.0, 'Quantity vs Discount')

# %%
sns.lineplot(x=data['Region'], y=data['Sales'])
plt.title("Region vs Sales")
# Out:
# Text(0.5, 1.0, 'Region vs Sales')

# %% [markdown]
# Co-Relation Matrices

# %%
corr=data.corr()
sns.heatmap(corr, annot=True, cmap='hot')

# %%
data=data.drop(['Postal Code'],axis=1)#Dropping postal code column

# %% [markdown]
# 6.Pair Plots

# %%
sns.pairplot(data,hue='Segment')

# %%
sns.pairplot(data,hue='Region')

# %%
sns.pairplot(mydata,hue='Category')

# %%
sns.pairplot(data,hue='Sub-Category')

# %% [markdown]
# Pie Charts

# %%
plt.figure(figsize=(12,9))
data['Category'].value_counts().plot.pie()
plt.show()

# %%
plt.figure(figsize=(12,9))
data['Sub-Category'].value_counts().plot.pie()
plt.show()

# %%
plt.figure(figsize=(12,9))
data['Segment'].value_counts().plot.pie()
plt.show()

# %%
plt.figure(figsize=(12,9))
mydata['Ship Mode'].value_counts().plot.pie()
plt.show()

# %%
plt.figure(figsize=(12,9))
data['Region'].value_counts().plot.pie()
plt.show()

# %%
plt.figure(figsize=(20,20))
data['State'].value_counts().plot.pie()
plt.show()
